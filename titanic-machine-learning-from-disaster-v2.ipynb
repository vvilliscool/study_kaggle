# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
train = pd.read_csv('../input/titanic/train.csv')
test = pd.read_csv('../input/titanic/test.csv')

# %%
train.head()

# %%
test.head()

# %%
test.info()

# %%
sel = ['Pclass','SibSp','Parch']
X = train[sel]
y = train['Survived']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    stratify=y, 
                                                    test_size = 0.3,
                                                    random_state=77)

# %%
tree = DecisionTreeClassifier(max_depth=2, random_state=0)
tree.fit(X_train, y_train)

print("훈련 세트 정확도 : {:.3f}".format(tree.score(X_train, y_train)))
print("테스트 세트 정확도 : {:.3f}".format(tree.score(X_test, y_test)))

# %%
for i in range(1,20,1):
  tree = DecisionTreeClassifier(max_depth=i, random_state=0)
  tree.fit(X_train, y_train)
  print(f"max_depth : {i}")
  print("훈련 세트 정확도 : {:.3f}".format(tree.score(X_train, y_train)))
  print("테스트 세트 정확도 : {:.3f}".format(tree.score(X_test, y_test)))

# %% [markdown]
# max_depth 7이후 정확도 향상이 보이지 않음

# %%
for i in range(5,50,5):
  tree = DecisionTreeClassifier(max_depth=i, random_state=0)
  tree.fit(X_train, y_train)
  print(f"max_depth : {i}")
  print("훈련 세트 정확도 : {:.3f}".format(tree.score(X_train, y_train)))
  print("테스트 세트 정확도 : {:.3f}".format(tree.score(X_test, y_test)))

# %%
tr = DecisionTreeClassifier(max_depth=7, random_state=0)
tr.fit(X_train, y_train)

# %%
tr.score(X_train, y_train)

# %%
tr.score(X_test, y_test)

# %%
pred = tr.predict(test[sel])

# %%
pred

# %%
sub = pd.read_csv('../input/titanic/gender_submission.csv')

# %%
sub.head()

# %%
subm = pd.DataFrame(test.PassengerId)

# %%
subm['Survived'] = pred
subm

# %%
subm.to_csv("./titanic_ML_pred.csv", index=False)

# %%
# result : 0.69617
